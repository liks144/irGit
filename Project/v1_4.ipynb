# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
import logging

# %%
import pickle
def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
log_fmt = "[%(asctime)s] %(levelname)s in %(module)s: %(message)s"
logging.basicConfig(format=log_fmt, level=logging.INFO)

import warnings
warnings.filterwarnings('ignore')
def extract_day(s):
    return s.apply(lambda x: int(x.split('-')[0][1:]))
def extract_hour(s):
    return s.apply(lambda x: int(x.split('-')[1][1:]))

base_path = 'data_set_0926'

# %%
#加载邀请数据
train = pd.read_csv(f'{base_path}/invite_info_0926.txt', sep='\t', header=None)
train.columns = ['qid', 'uid', 'dt', 'label']
logging.info("invite %s", train.shape)

test = pd.read_csv(f'{base_path}/invite_info_evaluate_1_0926.txt', sep='\t', header=None)
test.columns = ['qid', 'uid', 'dt']
logging.info("test %s", test.shape)

sub = test.copy()
sub_size = len(sub)

train['day'] = extract_day(train['dt'])
train['hour'] = extract_hour(train['dt'])
test['day'] = extract_day(test['dt'])
test['hour'] = extract_hour(test['dt'])

del train['dt'], test['dt']
# Out:
# [2019-12-17 00:06:56,328] INFO in <ipython-input-4-b836fd75a8ca>: invite (9489162, 4)
# [2019-12-17 00:06:59,491] INFO in <ipython-input-4-b836fd75a8ca>: test (1141683, 3)

# %%
#加载问题
ques = pd.read_csv(f'{base_path}/question_info_0926.txt', header=None, sep='\t')
ques.columns = ['qid', 'q_dt', 'title_t1', 'title_t2', 'desc_t1', 'desc_t2', 'topic']
del ques['title_t1'], ques['title_t2'], ques['desc_t1'], ques['desc_t2']
logging.info("ques %s", ques.shape)

ques['q_day'] = extract_day(ques['q_dt'])
ques['q_hour'] = extract_hour(ques['q_dt'])
del ques['q_dt']
# Out:
# [2019-12-17 00:08:03,760] INFO in <ipython-input-5-5996cc9bc826>: ques (1829900, 3)

# %%
#加载回答
ans = pd.read_csv(f'{base_path}/answer_info_0926.txt', header=None, sep='\t')
ans.columns = ['aid', 'qid', 'uid', 'ans_dt','ans_t1','ans_t2','is_good','is_rec','is_dest','has_img',
               'has_video', 'word_count', 'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
               'reci_xxx', 'reci_no_help', 'reci_dis']
del ans['ans_t1'], ans['ans_t2']
logging.info("ans %s", ans.shape)

ans['a_day'] = extract_day(ans['ans_dt'])
ans['a_hour'] = extract_hour(ans['ans_dt'])
del ans['ans_dt']

ans = pd.merge(ans, ques, on='qid')
del ques
# Out:
# [2019-12-17 00:13:25,342] INFO in <ipython-input-6-ac73b4ea1d3f>: ans (4513735, 18)

# %%
#回答距提问的天数
ans['diff_qa_days'] = ans['a_day'] - ans['q_day']

#时间窗口划分
# train
# val
train_start = 3838
train_end = 3867

val_start = 3868
val_end = 3874

#这里标示训练集起始
label_end = 3867
label_start = label_end - 6

train_label_feature_end = label_end - 7
train_label_feature_start = train_label_feature_end - 22

train_ans_feature_end = label_end - 7
train_ans_feature_start = train_ans_feature_end - 50

val_label_feature_end = val_start - 1
val_label_feature_start = val_label_feature_end - 22

val_ans_feature_end = val_start - 1
val_ans_feature_start = val_ans_feature_end - 50

train_label_feature = train[(train['day'] >= train_label_feature_start) & (train['day'] <= train_label_feature_end)]
logging.info("train_label_feature %s", train_label_feature.shape)

val_label_feature = train[(train['day'] >= val_label_feature_start) & (train['day'] <= val_label_feature_end)]
logging.info("val_label_feature %s", val_label_feature.shape)

train_label = train[(train['day'] > train_label_feature_end)]

logging.info("train feature start %s end %s, label start %s end %s", train_label_feature['day'].min(),
             train_label_feature['day'].max(), train_label['day'].min(), train_label['day'].max())

logging.info("test feature start %s end %s, label start %s end %s", val_label_feature['day'].min(),
             val_label_feature['day'].max(), test['day'].min(), test['day'].max())

#确定ans的时间范围
# 3807~3874
train_ans_feature = ans[(ans['a_day'] >= train_ans_feature_start) & (ans['a_day'] <= train_ans_feature_end)]

val_ans_feature = ans[(ans['a_day'] >= val_ans_feature_start) & (ans['a_day'] <= val_ans_feature_end)]

logging.info("train ans feature %s, start %s end %s", train_ans_feature.shape, train_ans_feature['a_day'].min(),
             train_ans_feature['a_day'].max())

logging.info("val ans feature %s, start %s end %s", val_ans_feature.shape, val_ans_feature['a_day'].min(),
             val_ans_feature['a_day'].max())

fea_cols = ['is_good', 'is_rec', 'is_dest', 'has_img', 'has_video', 'word_count',
            'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
            'reci_xxx', 'reci_no_help', 'reci_dis', 'diff_qa_days']
# Out:
# [2019-12-17 00:19:32,778] INFO in <ipython-input-7-c0b3e11102a1>: train_label_feature (6895493, 5)
# [2019-12-17 00:19:33,830] INFO in <ipython-input-7-c0b3e11102a1>: val_label_feature (7583553, 5)
# [2019-12-17 00:19:34,363] INFO in <ipython-input-7-c0b3e11102a1>: train feature start 3838 end 3860, label start 3861 end 3867
# [2019-12-17 00:19:34,410] INFO in <ipython-input-7-c0b3e11102a1>: test feature start 3845 end 3867, label start 3868 end 3874
# [2019-12-17 00:19:41,167] INFO in <ipython-input-7-c0b3e11102a1>: train ans feature (3700178, 23), start 3810 end 3860
# [2019-12-17 00:19:41,207] INFO in <ipython-input-7-c0b3e11102a1>: val ans feature (3992334, 23), start 3817 end 3867

# %%
print(ans.columns)
# Out:
# Index(['aid', 'qid', 'uid', 'is_good', 'is_rec', 'is_dest', 'has_img',
#        'has_video', 'word_count', 'reci_cheer', 'reci_uncheer', 'reci_comment',
#        'reci_mark', 'reci_tks', 'reci_xxx', 'reci_no_help', 'reci_dis',
#        'a_day', 'a_hour', 'topic', 'q_day', 'q_hour', 'diff_qa_days'],
#       dtype='object')

# %%
def to_array(df,x):
    col=df.iloc[:,x]
    #取表中的第x+1列的所有值
    arr =list(col.values)
    return arr

# %%
uid_list = to_array(ans,2)

# %%
qid_list = to_array(ans,1)

# %%
topic_list = to_array(ans,19)

# %%
len(topic_list)
# Out:
# 4513735

# %%
topic_list
# Out:
# ['T381,T8211,T3144,T4936,T823',
#  'T381,T8211,T3144,T4936,T823',
#  'T381,T8211,T3144,T4936,T823',
#  'T381,T8211,T3144,T4936,T823',
#  'T5490,T2180,T17098',
#  'T5490,T2180,T17098',
#  'T5490,T2180,T17098',
#  'T5490,T2180,T17098',
#  'T5490,T2180,T17098',
#  'T5490,T2180,T17098',
#  'T8716,T10196,T8767',
#  'T8716,T10196,T8767',
#  'T8716,T10196,T8767',
#  'T8716,T10196,T8767',
#  'T258',
#  'T258',
#  'T258',
#  'T258',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T95,T545',
#  'T1144,T545,T258,T95',
#  'T1144,T545,T258,T95',
#  'T1144,T545,T258,T95',
#  'T1144,T545,T258,T95',
#  'T1144,T545,T258,T95',
#  'T1144,T545,T258,T95',
#  'T1144,T545,T258,T95',
#  'T1144,T545,T258,T95',
#  'T106,T95,T1515',
#  'T106,T95,T1515',
#  'T106,T95,T1515',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T248,T591,T687,T11258,T12762',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T4416,T5827,T455',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T402,T5126,T1856,T570',
#  'T1986,T258,T95',
#  'T1986,T258,T95',
#  'T1986,T258,T95',
#  'T1986,T258,T95',
#  'T1986,T258,T95',
#  'T1986,T258,T95',
#  'T8131,T108,T5052,T6,T41',
#  'T31,T245,T2274,T542',
#  'T31,T245,T2274,T542',
#  'T31,T245,T2274,T542',
#  'T31,T245,T2274,T542',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T12,T3,T289',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  'T10223,T116,T1606,T680',
#  ...]

# %%
def static(usrList,tpcList):
# 统计 用户-回答涉及话题
    member_topic = {}
    for user,topicraw in zip(usrList,tpcList): #这里用的还是dataframe
        if topicraw == '-1':
            pass
        else:
            list = topicraw.split(",")
            if user in member_topic:
                for i in list:
                    if i in member_topic[user]:
                        member_topic[user][i] += 1;
                    else:
                        member_topic[user][i] = 1;
            else:
                member_topic[user] = dict(zip(list,[1]*len(list)))
    return member_topic

# %%
member_topic = static(uid_list,topic_list)

# %%
ques = pd.read_csv(f'{base_path}/question_info_0926.txt', header=None, sep='\t')
ques.columns = ['qid', 'q_dt', 'title_t1', 'title_t2', 'desc_t1', 'desc_t2', 'topic']
del ques['title_t1'], ques['title_t2'], ques['desc_t1'], ques['desc_t2']
del ques['q_dt']

# %%
print(ques.columns)
# Out:
# Index(['qid', 'topic'], dtype='object')

# %%
QUESTION_list = to_array(ques,0)
TOPIC_list = to_array(ques,1)

# %%
len(TOPIC_list)
# Out:
# 1829900

# %%
ques_topic = {}
#topic是-1的也在里面
for ques,topic in zip(QUESTION_list,TOPIC_list):
    if topic == '-1':
        List = []
    else:
        List = topic.split(",")
    if ques in ques_topic:
        print("问题重复")
        ques_topic[ques].update(List)
    else:
        ques_topic[ques] = set(List)

# %%
save_obj(ques_topic,"ques_topic") #ques_topic是 字典-集合结构 只包含涉及的topic
save_obj(member_topic,"member_topic")#member_topic是 字典-字典结构 保存每个topic出现次数

# %%
print(train_label.columns)
# Out:
# Index(['qid', 'uid', 'label', 'day', 'hour'], dtype='object')

# %%
print(train_label.iloc[0,0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-05af7658ab1a> in <module>
# ----> 1 print(train_label.iloc[0,0].type)
#
# AttributeError: 'str' object has no attribute 'type'

# %%
train_qid_list = to_array(train_label,0)
train_uid_list = to_array(train_label,1)

# %%
len(UQscore)
# Out:
# 2593669

# %%
def score(useridlist,quesidlist):
#     用static统计出来的member_topic给每个U-Q打分
    global member_topic
    global ques_topic
    score = []
    for userid,quesid in zip(useridlist,quesidlist):
        score_temp = 0
        if userid not in member_topic:
            score.append(0)
#             print('member %s没找到'%userid)
        elif quesid not in ques_topic:
            score.append(0)
#             print('问题 %s 没找到'%quesid)
        elif not ques_topic[quesid]:
            score.append(3)
        else:
#             print('member %s回答了问题'%userid)
            topic_set = ques_topic[quesid]
            for i in topic_set:
                if i in member_topic[userid]:
                    score_temp += member_topic[userid][i]
            score.append(score_temp)
    return score

# %%
UQscore = score(train_uid_list,train_qid_list)

# %%
train_label['UQscore'] = UQscore

# %%
print(test.columns)
# Out:
# Index(['qid', 'uid', 'day', 'hour'], dtype='object')

# %%
test_qid_list = to_array(test,0)
test_uid_list = to_array(test,1)

# %%
UQscore_test = score(test_uid_list,test_qid_list)

# %%
len(test_uid_list)
# Out:
# 1141683

# %%
test['UQscore'] = UQscore_test

# %%
test_qid_list = to_array(train_label_feature,0)
test_uid_list = to_array(train_label_feature,1)

# %%
def UQSCORE(df,x,y):
#     一个大的计算UQSCORE的函数
#     xy 是user 和 ques column的序号
    Q_LST = to_array(df,x)
    U_LST = to_array(df,y)
    if len(df.iloc[:,x]) == len(U_LST) and len(df.iloc[:,y]) == len(Q_LST):
        print("等长不需填充")
    else:
        return
    UQscore = score(U_LST,Q_LST)
    df['UQscore'] = UQscore
    return

# %%
len(train_label_feature.iloc[:,1])
# Out:
# 6895493

# %%
UQSCORE(train_label_feature,0,1)
# Out:
# 等长不需填充

# %%
print(val_label_feature.columns)
# Out:
# Index(['qid', 'uid', 'label', 'day', 'hour', 'UQscore'], dtype='object')

# %%
UQSCORE(val_label_feature,0,1)
# Out:
# 等长不需填充

# %%
del ques_topic,member_topic

# %%
def extract_feature1(target, label_feature, ans_feature):
    # 问题特征
    t1 = label_feature.groupby('qid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['qid', 'q_inv_mean', 'q_inv_sum', 'q_inv_std', 'q_inv_count']
    target = pd.merge(target, t1, on='qid', how='left')

    # 用户特征
    t1 = label_feature.groupby('uid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['uid', 'u_inv_mean', 'u_inv_sum', 'u_inv_std', 'u_inv_count']
    target = pd.merge(target, t1, on='uid', how='left')
    #
    # train_size = len(train)
    # data = pd.concat((train, test), sort=True)

#     t1 = label_feature.groupby('qid')['UQscore'].agg(['mean', 'std', 'count']).reset_index()
#     t1.columns = ['qid', 'UQS_inv_mean', 'UQS_inv_std', 'UQS_inv_count']
#     target = pd.merge(target, t1, on='qid', how='left')
    
#     t1 = label_feature.groupby('uid')['UQscore'].agg(['mean', 'std', 'count']).reset_index()
#     t1.columns = ['uid', 'UQS_inv_mean','UQS_inv_std', 'UQS_inv_count']
#     target = pd.merge(target, t1, on='uid', how='left')
    
    
    # 回答部分特征
    t1 = ans_feature.groupby('qid')['aid'].count().reset_index()
    t1.columns = ['qid', 'q_ans_count']
    target = pd.merge(target, t1, on='qid', how='left')

    t1 = ans_feature.groupby('uid')['aid'].count().reset_index()
    t1.columns = ['uid', 'u_ans_count']
    target = pd.merge(target, t1, on='uid', how='left')

    for col in fea_cols:
        t1 = ans_feature.groupby('uid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['uid', f'u_{col}_sum', f'u_{col}_max', f'u_{col}_mean']
        target = pd.merge(target, t1, on='uid', how='left')

        t1 = ans_feature.groupby('qid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['qid', f'q_{col}_sum', f'q_{col}_max', f'q_{col}_mean']
        target = pd.merge(target, t1, on='qid', how='left')
        logging.info("extract %s", col)
    return target

# %%
# train_label = extract_feature1(train_label, train_label_feature, train_ans_feature)
test = extract_feature1(test, val_label_feature, val_ans_feature)
# Out:
# [2019-12-17 02:44:05,991] INFO in <ipython-input-101-01eadaa08d0c>: extract is_good
# [2019-12-17 02:44:20,950] INFO in <ipython-input-101-01eadaa08d0c>: extract is_rec
# [2019-12-17 02:44:35,987] INFO in <ipython-input-101-01eadaa08d0c>: extract is_dest
# [2019-12-17 02:44:51,044] INFO in <ipython-input-101-01eadaa08d0c>: extract has_img
# [2019-12-17 02:45:07,295] INFO in <ipython-input-101-01eadaa08d0c>: extract has_video
# [2019-12-17 02:45:26,420] INFO in <ipython-input-101-01eadaa08d0c>: extract word_count
# [2019-12-17 02:45:43,610] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_cheer
# [2019-12-17 02:45:59,738] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_uncheer
# [2019-12-17 02:46:18,948] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_comment
# [2019-12-17 02:46:35,847] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_mark
# [2019-12-17 02:46:52,977] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_tks
# [2019-12-17 02:47:11,241] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_xxx
# [2019-12-17 02:47:29,679] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_no_help
# [2019-12-17 02:47:48,938] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_dis
# [2019-12-17 02:48:07,096] INFO in <ipython-input-101-01eadaa08d0c>: extract diff_qa_days
# [2019-12-17 02:49:07,666] INFO in <ipython-input-101-01eadaa08d0c>: extract is_good
# [2019-12-17 02:49:21,725] INFO in <ipython-input-101-01eadaa08d0c>: extract is_rec
# [2019-12-17 02:49:35,157] INFO in <ipython-input-101-01eadaa08d0c>: extract is_dest
# [2019-12-17 02:49:48,437] INFO in <ipython-input-101-01eadaa08d0c>: extract has_img
# [2019-12-17 02:50:03,257] INFO in <ipython-input-101-01eadaa08d0c>: extract has_video
# [2019-12-17 02:50:17,395] INFO in <ipython-input-101-01eadaa08d0c>: extract word_count
# [2019-12-17 02:50:32,222] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_cheer
# [2019-12-17 02:50:46,687] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_uncheer
# [2019-12-17 02:51:01,060] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_comment
# [2019-12-17 02:51:16,876] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_mark
# [2019-12-17 02:51:30,771] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_tks
# [2019-12-17 02:51:46,343] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_xxx
# [2019-12-17 02:52:00,478] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_no_help
# [2019-12-17 02:52:15,439] INFO in <ipython-input-101-01eadaa08d0c>: extract reci_dis
# [2019-12-17 02:52:31,470] INFO in <ipython-input-101-01eadaa08d0c>: extract diff_qa_days

# %%
# 特征提取结束
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)
assert len(test) == sub_size

# 加载用户
user = pd.read_csv(f'{base_path}/member_info_0926.txt', header=None, sep='\t')
user.columns = ['uid', 'gender', 'creat_keyword', 'level', 'hot', 'reg_type', 'reg_plat', 'freq', 'uf_b1', 'uf_b2',
                'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'score', 'follow_topic',
                'inter_topic']
del user['follow_topic'], user['inter_topic']
logging.info("user %s", user.shape)

unq = user.nunique()
logging.info("user unq %s", unq)

for x in unq[unq == 1].index:
    del user[x]
    logging.info('del unq==1 %s', x)

t = user.dtypes
cats = [x for x in t[t == 'object'].index if x not in ['follow_topic', 'inter_topic', 'uid']]
logging.info("user cat %s", cats)

for d in cats:
    lb = LabelEncoder()
    user[d] = lb.fit_transform(user[d])
    logging.info('encode %s', d)

q_lb = LabelEncoder()
q_lb.fit(list(train_label['qid'].astype(str).values) + list(test['qid'].astype(str).values))
train_label['qid_enc'] = q_lb.transform(train_label['qid'])
test['qid_enc'] = q_lb.transform(test['qid'])

u_lb = LabelEncoder()
u_lb.fit(user['uid'])
train_label['uid_enc'] = u_lb.transform(train_label['uid'])
test['uid_enc'] = u_lb.transform(test['uid'])

# merge user
train_label = pd.merge(train_label, user, on='uid', how='left')
test = pd.merge(test, user, on='uid', how='left')
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

data = pd.concat((train_label, test), axis=0, sort=True)
del test

# count编码
count_fea = ['uid_enc', 'qid_enc', 'gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
for feat in count_fea:
    col_name = '{}_count'.format(feat)
    data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
    data.loc[data[col_name] < 2, feat] = -1
    data[feat] += 1
    data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
    data[col_name] = (data[col_name] - data[col_name].min()) / (data[col_name].max() - data[col_name].min())
    # 

# 问题被回答的次数

# 压缩数据
t = data.dtypes
for x in t[t == 'int64'].index:
    data[x] = data[x].astype('int32')

for x in t[t == 'float64'].index:
    data[x] = data[x].astype('float32')

data['wk'] = data['day'] % 7

feature_cols = [x for x in data.columns if x not in ('label', 'uid', 'qid', 'dt', 'day')]
# target编码
logging.info("feature size %s", len(feature_cols))
# Out:
# [2019-12-17 02:53:33,608] INFO in <ipython-input-103-567af4893ef3>: train shape (2593669, 112), test shape (1141683, 111)
# [2019-12-17 02:53:47,232] INFO in <ipython-input-103-567af4893ef3>: user (1931654, 19)
# [2019-12-17 02:53:51,347] INFO in <ipython-input-103-567af4893ef3>: user unq uid              1931654
# gender                 3
# creat_keyword          1
# level                  1
# hot                    1
# reg_type               1
# reg_plat               1
# freq                   5
# uf_b1                  2
# uf_b2                  2
# uf_b3                  2
# uf_b4                  2
# uf_b5                  2
# uf_c1               2561
# uf_c2                291
# uf_c3                428
# uf_c4               1556
# uf_c5                  2
# score                732
# dtype: int64
# [2019-12-17 02:53:51,406] INFO in <ipython-input-103-567af4893ef3>: del unq==1 creat_keyword
# [2019-12-17 02:53:51,418] INFO in <ipython-input-103-567af4893ef3>: del unq==1 level
# [2019-12-17 02:53:51,419] INFO in <ipython-input-103-567af4893ef3>: del unq==1 hot
# [2019-12-17 02:53:51,559] INFO in <ipython-input-103-567af4893ef3>: del unq==1 reg_type
# [2019-12-17 02:53:51,659] INFO in <ipython-input-103-567af4893ef3>: del unq==1 reg_plat
# [2019-12-17 02:53:51,693] INFO in <ipython-input-103-567af4893ef3>: user cat ['gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
# [2019-12-17 02:53:52,312] INFO in <ipython-input-103-567af4893ef3>: encode gender
# [2019-12-17 02:53:53,015] INFO in <ipython-input-103-567af4893ef3>: encode freq
# [2019-12-17 02:53:53,534] INFO in <ipython-input-103-567af4893ef3>: encode uf_c1
# [2019-12-17 02:53:54,126] INFO in <ipython-input-103-567af4893ef3>: encode uf_c2
# [2019-12-17 02:53:54,701] INFO in <ipython-input-103-567af4893ef3>: encode uf_c3
# [2019-12-17 02:53:55,152] INFO in <ipython-input-103-567af4893ef3>: encode uf_c4
# [2019-12-17 02:53:55,675] INFO in <ipython-input-103-567af4893ef3>: encode uf_c5
# [2019-12-17 02:54:26,370] INFO in <ipython-input-103-567af4893ef3>: train shape (2593669, 127), test shape (1141683, 126)
# [2019-12-17 02:59:56,368] INFO in <ipython-input-103-567af4893ef3>: feature size 133

# %%
X_train_all = data.iloc[:len(train_label)][feature_cols]
y_train_all = data.iloc[:len(train_label)]['label']
test = data.iloc[len(train_label):]
del data
assert len(test) == sub_size

logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for index, (train_idx, val_idx) in enumerate(fold.split(X=X_train_all, y=y_train_all)):
    break

X_train, X_val, y_train, y_val = X_train_all.iloc[train_idx][feature_cols], X_train_all.iloc[val_idx][feature_cols], \
                                 y_train_all.iloc[train_idx], \
                                 y_train_all.iloc[val_idx]
del train_label, X_train_all
# Out:
# [2019-12-17 03:01:35,377] INFO in <ipython-input-104-bbd36cef4c67>: train shape (2593669, 127), test shape (1141683, 137)

# %%
model_lgb = LGBMClassifier(learning_rate=0.05,n_estimators=700, n_jobs=-1, 
                           objective='binary', seed=1000, silent=True, 
                           device="gpu",gpu_platform_id = 0,gpu_device_id = 2,
                           max_bin=63,min_child_samples=128)

model_lgb.fit(X_train, y_train,
              eval_metric=['logloss', 'auc'],
              eval_set=[(X_val, y_val)],
              early_stopping_rounds=10)

sub['label'] = model_lgb.predict_proba(test[feature_cols])[:, 1]

sub.to_csv('result781.txt', index=None, header=None, sep='\t')

save_obj(model_lgb,'model.model_lgb_781')
# Out:
# [1]	valid_0's auc: 0.836028	valid_0's binary_logloss: 0.425656
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's auc: 0.838512	valid_0's binary_logloss: 0.414124
# [3]	valid_0's auc: 0.843415	valid_0's binary_logloss: 0.404366
# [4]	valid_0's auc: 0.844364	valid_0's binary_logloss: 0.395628
# [5]	valid_0's auc: 0.848432	valid_0's binary_logloss: 0.388112
# [6]	valid_0's auc: 0.84985	valid_0's binary_logloss: 0.381268
# [7]	valid_0's auc: 0.854282	valid_0's binary_logloss: 0.375064
# [8]	valid_0's auc: 0.855068	valid_0's binary_logloss: 0.369524
# [9]	valid_0's auc: 0.856683	valid_0's binary_logloss: 0.364332
# [10]	valid_0's auc: 0.857744	valid_0's binary_logloss: 0.359668
# [11]	valid_0's auc: 0.862475	valid_0's binary_logloss: 0.355177
# [12]	valid_0's auc: 0.864106	valid_0's binary_logloss: 0.351076
# [13]	valid_0's auc: 0.865583	valid_0's binary_logloss: 0.347246
# [14]	valid_0's auc: 0.866243	valid_0's binary_logloss: 0.343804
# [15]	valid_0's auc: 0.867387	valid_0's binary_logloss: 0.340314
# [16]	valid_0's auc: 0.868342	valid_0's binary_logloss: 0.337101
# [17]	valid_0's auc: 0.869154	valid_0's binary_logloss: 0.334171
# [18]	valid_0's auc: 0.869557	valid_0's binary_logloss: 0.331509
# [19]	valid_0's auc: 0.870291	valid_0's binary_logloss: 0.328941
# [20]	valid_0's auc: 0.871188	valid_0's binary_logloss: 0.326496
# [21]	valid_0's auc: 0.872091	valid_0's binary_logloss: 0.324233
# [22]	valid_0's auc: 0.872529	valid_0's binary_logloss: 0.322119
# [23]	valid_0's auc: 0.872949	valid_0's binary_logloss: 0.32011
# [24]	valid_0's auc: 0.873676	valid_0's binary_logloss: 0.318218
# [25]	valid_0's auc: 0.874024	valid_0's binary_logloss: 0.316485
# [26]	valid_0's auc: 0.874641	valid_0's binary_logloss: 0.314762
# [27]	valid_0's auc: 0.875344	valid_0's binary_logloss: 0.313156
# [28]	valid_0's auc: 0.875853	valid_0's binary_logloss: 0.311633
# [29]	valid_0's auc: 0.876389	valid_0's binary_logloss: 0.310273
# [30]	valid_0's auc: 0.876984	valid_0's binary_logloss: 0.308829
# [31]	valid_0's auc: 0.877551	valid_0's binary_logloss: 0.307501
# [32]	valid_0's auc: 0.878183	valid_0's binary_logloss: 0.306138
# [33]	valid_0's auc: 0.878641	valid_0's binary_logloss: 0.304992
# [34]	valid_0's auc: 0.879105	valid_0's binary_logloss: 0.303821
# [35]	valid_0's auc: 0.879471	valid_0's binary_logloss: 0.30274
# [36]	valid_0's auc: 0.880012	valid_0's binary_logloss: 0.301667
# [37]	valid_0's auc: 0.880472	valid_0's binary_logloss: 0.300641
# [38]	valid_0's auc: 0.880835	valid_0's binary_logloss: 0.299731
# [39]	valid_0's auc: 0.881168	valid_0's binary_logloss: 0.298812
# [40]	valid_0's auc: 0.881624	valid_0's binary_logloss: 0.297868
# [41]	valid_0's auc: 0.88199	valid_0's binary_logloss: 0.297059
# [42]	valid_0's auc: 0.882394	valid_0's binary_logloss: 0.296313
# [43]	valid_0's auc: 0.882742	valid_0's binary_logloss: 0.295537
# [44]	valid_0's auc: 0.883128	valid_0's binary_logloss: 0.294713
# [45]	valid_0's auc: 0.883532	valid_0's binary_logloss: 0.293913
# [46]	valid_0's auc: 0.884003	valid_0's binary_logloss: 0.29307
# [47]	valid_0's auc: 0.884301	valid_0's binary_logloss: 0.292379
# [48]	valid_0's auc: 0.884719	valid_0's binary_logloss: 0.291608
# [49]	valid_0's auc: 0.88511	valid_0's binary_logloss: 0.290932
# [50]	valid_0's auc: 0.885387	valid_0's binary_logloss: 0.290317
# [51]	valid_0's auc: 0.885851	valid_0's binary_logloss: 0.289634
# [52]	valid_0's auc: 0.886146	valid_0's binary_logloss: 0.289045
# [53]	valid_0's auc: 0.886491	valid_0's binary_logloss: 0.288437
# [54]	valid_0's auc: 0.886918	valid_0's binary_logloss: 0.287835
# [55]	valid_0's auc: 0.887219	valid_0's binary_logloss: 0.287322
# [56]	valid_0's auc: 0.887444	valid_0's binary_logloss: 0.28684
# [57]	valid_0's auc: 0.887841	valid_0's binary_logloss: 0.286293
# [58]	valid_0's auc: 0.888087	valid_0's binary_logloss: 0.285849
# [59]	valid_0's auc: 0.888435	valid_0's binary_logloss: 0.28536
# [60]	valid_0's auc: 0.88866	valid_0's binary_logloss: 0.284964
# [61]	valid_0's auc: 0.888965	valid_0's binary_logloss: 0.284495
# [62]	valid_0's auc: 0.889156	valid_0's binary_logloss: 0.284105
# [63]	valid_0's auc: 0.889454	valid_0's binary_logloss: 0.283659
# [64]	valid_0's auc: 0.889706	valid_0's binary_logloss: 0.283255
# [65]	valid_0's auc: 0.889926	valid_0's binary_logloss: 0.282873
# [66]	valid_0's auc: 0.890159	valid_0's binary_logloss: 0.282493
# [67]	valid_0's auc: 0.89042	valid_0's binary_logloss: 0.282138
# [68]	valid_0's auc: 0.890649	valid_0's binary_logloss: 0.281777
# [69]	valid_0's auc: 0.890841	valid_0's binary_logloss: 0.281419
# [70]	valid_0's auc: 0.891012	valid_0's binary_logloss: 0.281093
# [71]	valid_0's auc: 0.891172	valid_0's binary_logloss: 0.280807
# [72]	valid_0's auc: 0.891333	valid_0's binary_logloss: 0.280505
# [73]	valid_0's auc: 0.891539	valid_0's binary_logloss: 0.28019
# [74]	valid_0's auc: 0.891735	valid_0's binary_logloss: 0.27986
# [75]	valid_0's auc: 0.891882	valid_0's binary_logloss: 0.279593
# [76]	valid_0's auc: 0.892085	valid_0's binary_logloss: 0.279291
# [77]	valid_0's auc: 0.892232	valid_0's binary_logloss: 0.279023
# [78]	valid_0's auc: 0.892382	valid_0's binary_logloss: 0.278769
# [79]	valid_0's auc: 0.892537	valid_0's binary_logloss: 0.278509
# [80]	valid_0's auc: 0.892676	valid_0's binary_logloss: 0.278281
# [81]	valid_0's auc: 0.892833	valid_0's binary_logloss: 0.27802
# [82]	valid_0's auc: 0.892975	valid_0's binary_logloss: 0.277779
# [83]	valid_0's auc: 0.893106	valid_0's binary_logloss: 0.277557
# [84]	valid_0's auc: 0.893251	valid_0's binary_logloss: 0.277346
# [85]	valid_0's auc: 0.893376	valid_0's binary_logloss: 0.277144
# [86]	valid_0's auc: 0.893523	valid_0's binary_logloss: 0.276939
# [87]	valid_0's auc: 0.89369	valid_0's binary_logloss: 0.276686
# [88]	valid_0's auc: 0.893814	valid_0's binary_logloss: 0.276482
# [89]	valid_0's auc: 0.893945	valid_0's binary_logloss: 0.276274
# [90]	valid_0's auc: 0.894059	valid_0's binary_logloss: 0.276078
# [91]	valid_0's auc: 0.894175	valid_0's binary_logloss: 0.275903
# [92]	valid_0's auc: 0.894285	valid_0's binary_logloss: 0.275732
# [93]	valid_0's auc: 0.894402	valid_0's binary_logloss: 0.275543
# [94]	valid_0's auc: 0.894498	valid_0's binary_logloss: 0.275369
# [95]	valid_0's auc: 0.8946	valid_0's binary_logloss: 0.275215
# [96]	valid_0's auc: 0.894724	valid_0's binary_logloss: 0.275062
# [97]	valid_0's auc: 0.894815	valid_0's binary_logloss: 0.274902
# [98]	valid_0's auc: 0.894914	valid_0's binary_logloss: 0.274759
# [99]	valid_0's auc: 0.895001	valid_0's binary_logloss: 0.274622
# [100]	valid_0's auc: 0.895129	valid_0's binary_logloss: 0.274413
# [101]	valid_0's auc: 0.895221	valid_0's binary_logloss: 0.274258
# [102]	valid_0's auc: 0.895329	valid_0's binary_logloss: 0.274078
# [103]	valid_0's auc: 0.895426	valid_0's binary_logloss: 0.273919
# [104]	valid_0's auc: 0.895502	valid_0's binary_logloss: 0.273784
# [105]	valid_0's auc: 0.895585	valid_0's binary_logloss: 0.273663
# [106]	valid_0's auc: 0.895674	valid_0's binary_logloss: 0.273539
# [107]	valid_0's auc: 0.895738	valid_0's binary_logloss: 0.273442
# [108]	valid_0's auc: 0.89582	valid_0's binary_logloss: 0.2733
# [109]	valid_0's auc: 0.895917	valid_0's binary_logloss: 0.273143
# [110]	valid_0's auc: 0.895982	valid_0's binary_logloss: 0.273043
# [111]	valid_0's auc: 0.896064	valid_0's binary_logloss: 0.272931
# [112]	valid_0's auc: 0.896141	valid_0's binary_logloss: 0.272802
# [113]	valid_0's auc: 0.896217	valid_0's binary_logloss: 0.272704
# [114]	valid_0's auc: 0.896319	valid_0's binary_logloss: 0.272553
# [115]	valid_0's auc: 0.896407	valid_0's binary_logloss: 0.272427
# [116]	valid_0's auc: 0.896491	valid_0's binary_logloss: 0.272301
# [117]	valid_0's auc: 0.896588	valid_0's binary_logloss: 0.272164
# [118]	valid_0's auc: 0.896653	valid_0's binary_logloss: 0.272063
# [119]	valid_0's auc: 0.896743	valid_0's binary_logloss: 0.271937
# [120]	valid_0's auc: 0.896804	valid_0's binary_logloss: 0.271839
# [121]	valid_0's auc: 0.896871	valid_0's binary_logloss: 0.271737
# [122]	valid_0's auc: 0.896955	valid_0's binary_logloss: 0.271627
# [123]	valid_0's auc: 0.897039	valid_0's binary_logloss: 0.271503
# [124]	valid_0's auc: 0.89711	valid_0's binary_logloss: 0.271399
# [125]	valid_0's auc: 0.897187	valid_0's binary_logloss: 0.271293
# [126]	valid_0's auc: 0.897252	valid_0's binary_logloss: 0.271201
# [127]	valid_0's auc: 0.897318	valid_0's binary_logloss: 0.271089
# [128]	valid_0's auc: 0.897384	valid_0's binary_logloss: 0.270979
# [129]	valid_0's auc: 0.897445	valid_0's binary_logloss: 0.270891
# [130]	valid_0's auc: 0.897519	valid_0's binary_logloss: 0.270781
# [131]	valid_0's auc: 0.897594	valid_0's binary_logloss: 0.270675
# [132]	valid_0's auc: 0.897696	valid_0's binary_logloss: 0.270554
# [133]	valid_0's auc: 0.897766	valid_0's binary_logloss: 0.270449
# [134]	valid_0's auc: 0.897833	valid_0's binary_logloss: 0.270355
# [135]	valid_0's auc: 0.897883	valid_0's binary_logloss: 0.270286
# [136]	valid_0's auc: 0.897933	valid_0's binary_logloss: 0.270215
# [137]	valid_0's auc: 0.89799	valid_0's binary_logloss: 0.270143
# [138]	valid_0's auc: 0.89803	valid_0's binary_logloss: 0.270074
# [139]	valid_0's auc: 0.89811	valid_0's binary_logloss: 0.269957
# [140]	valid_0's auc: 0.898172	valid_0's binary_logloss: 0.269872
# [141]	valid_0's auc: 0.898217	valid_0's binary_logloss: 0.269799
# [142]	valid_0's auc: 0.898263	valid_0's binary_logloss: 0.269741
# [143]	valid_0's auc: 0.898324	valid_0's binary_logloss: 0.269651
# [144]	valid_0's auc: 0.898403	valid_0's binary_logloss: 0.269554
# [145]	valid_0's auc: 0.898458	valid_0's binary_logloss: 0.269477
# [146]	valid_0's auc: 0.898541	valid_0's binary_logloss: 0.269362
# [147]	valid_0's auc: 0.898586	valid_0's binary_logloss: 0.269295
# [148]	valid_0's auc: 0.898635	valid_0's binary_logloss: 0.269219
# [149]	valid_0's auc: 0.898693	valid_0's binary_logloss: 0.269134
# [150]	valid_0's auc: 0.89876	valid_0's binary_logloss: 0.269031
# [151]	valid_0's auc: 0.898804	valid_0's binary_logloss: 0.26897
# [152]	valid_0's auc: 0.898848	valid_0's binary_logloss: 0.268916
# [153]	valid_0's auc: 0.898915	valid_0's binary_logloss: 0.26881
# [154]	valid_0's auc: 0.898967	valid_0's binary_logloss: 0.268724
# [155]	valid_0's auc: 0.899026	valid_0's binary_logloss: 0.268642
# [156]	valid_0's auc: 0.899074	valid_0's binary_logloss: 0.268577
# [157]	valid_0's auc: 0.899124	valid_0's binary_logloss: 0.268504
# [158]	valid_0's auc: 0.899183	valid_0's binary_logloss: 0.268406
# [159]	valid_0's auc: 0.89926	valid_0's binary_logloss: 0.268301
# [160]	valid_0's auc: 0.899302	valid_0's binary_logloss: 0.26824
# [161]	valid_0's auc: 0.899341	valid_0's binary_logloss: 0.268181
# [162]	valid_0's auc: 0.899383	valid_0's binary_logloss: 0.268121
# [163]	valid_0's auc: 0.899425	valid_0's binary_logloss: 0.268052
# [164]	valid_0's auc: 0.899463	valid_0's binary_logloss: 0.267999
# [165]	valid_0's auc: 0.899488	valid_0's binary_logloss: 0.267957
# [166]	valid_0's auc: 0.899558	valid_0's binary_logloss: 0.267875
# [167]	valid_0's auc: 0.899597	valid_0's binary_logloss: 0.267819
# [168]	valid_0's auc: 0.899651	valid_0's binary_logloss: 0.267734
# [169]	valid_0's auc: 0.899693	valid_0's binary_logloss: 0.26767
# [170]	valid_0's auc: 0.899738	valid_0's binary_logloss: 0.267608
# [171]	valid_0's auc: 0.899759	valid_0's binary_logloss: 0.267573
# [172]	valid_0's auc: 0.899804	valid_0's binary_logloss: 0.267514
# [173]	valid_0's auc: 0.899855	valid_0's binary_logloss: 0.267443
# [174]	valid_0's auc: 0.89989	valid_0's binary_logloss: 0.267384
# [175]	valid_0's auc: 0.899932	valid_0's binary_logloss: 0.267322
# [176]	valid_0's auc: 0.899968	valid_0's binary_logloss: 0.267271
# [177]	valid_0's auc: 0.900002	valid_0's binary_logloss: 0.267225
# [178]	valid_0's auc: 0.90004	valid_0's binary_logloss: 0.26716
# [179]	valid_0's auc: 0.90008	valid_0's binary_logloss: 0.267099
# [180]	valid_0's auc: 0.900129	valid_0's binary_logloss: 0.267037
# [181]	valid_0's auc: 0.900151	valid_0's binary_logloss: 0.267005
# [182]	valid_0's auc: 0.900183	valid_0's binary_logloss: 0.266958
# [183]	valid_0's auc: 0.900204	valid_0's binary_logloss: 0.266924
# [184]	valid_0's auc: 0.900245	valid_0's binary_logloss: 0.266857
# [185]	valid_0's auc: 0.900281	valid_0's binary_logloss: 0.266814
# [186]	valid_0's auc: 0.90031	valid_0's binary_logloss: 0.266772
# [187]	valid_0's auc: 0.900368	valid_0's binary_logloss: 0.266694
# [188]	valid_0's auc: 0.900408	valid_0's binary_logloss: 0.266636
# [189]	valid_0's auc: 0.900443	valid_0's binary_logloss: 0.266589
# [190]	valid_0's auc: 0.900477	valid_0's binary_logloss: 0.266529
# [191]	valid_0's auc: 0.900514	valid_0's binary_logloss: 0.266469
# [192]	valid_0's auc: 0.900554	valid_0's binary_logloss: 0.266416
# [193]	valid_0's auc: 0.900581	valid_0's binary_logloss: 0.266382
# [194]	valid_0's auc: 0.900617	valid_0's binary_logloss: 0.266334
# [195]	valid_0's auc: 0.900645	valid_0's binary_logloss: 0.266294
# [196]	valid_0's auc: 0.900679	valid_0's binary_logloss: 0.266247
# [197]	valid_0's auc: 0.900709	valid_0's binary_logloss: 0.266198
# [198]	valid_0's auc: 0.900738	valid_0's binary_logloss: 0.26616
# [199]	valid_0's auc: 0.90077	valid_0's binary_logloss: 0.266101
# [200]	valid_0's auc: 0.900814	valid_0's binary_logloss: 0.26604
# [201]	valid_0's auc: 0.900849	valid_0's binary_logloss: 0.265993
# [202]	valid_0's auc: 0.900872	valid_0's binary_logloss: 0.26596
# [203]	valid_0's auc: 0.900906	valid_0's binary_logloss: 0.265917
# [204]	valid_0's auc: 0.900925	valid_0's binary_logloss: 0.265883
# [205]	valid_0's auc: 0.900949	valid_0's binary_logloss: 0.265848
# [206]	valid_0's auc: 0.900972	valid_0's binary_logloss: 0.265812
# [207]	valid_0's auc: 0.901003	valid_0's binary_logloss: 0.265769
# [208]	valid_0's auc: 0.901049	valid_0's binary_logloss: 0.265706
# [209]	valid_0's auc: 0.901083	valid_0's binary_logloss: 0.26566
# [210]	valid_0's auc: 0.901115	valid_0's binary_logloss: 0.265611
# [211]	valid_0's auc: 0.901143	valid_0's binary_logloss: 0.26557
# [212]	valid_0's auc: 0.901179	valid_0's binary_logloss: 0.265527
# [213]	valid_0's auc: 0.901202	valid_0's binary_logloss: 0.265489
# [214]	valid_0's auc: 0.901243	valid_0's binary_logloss: 0.265428
# [215]	valid_0's auc: 0.901282	valid_0's binary_logloss: 0.265375
# [216]	valid_0's auc: 0.901313	valid_0's binary_logloss: 0.265335
# [217]	valid_0's auc: 0.901336	valid_0's binary_logloss: 0.265298
# [218]	valid_0's auc: 0.901372	valid_0's binary_logloss: 0.265249
# [219]	valid_0's auc: 0.901405	valid_0's binary_logloss: 0.265204
# [220]	valid_0's auc: 0.901446	valid_0's binary_logloss: 0.265149
# [221]	valid_0's auc: 0.901481	valid_0's binary_logloss: 0.265112
# [222]	valid_0's auc: 0.9015	valid_0's binary_logloss: 0.265081
# [223]	valid_0's auc: 0.901528	valid_0's binary_logloss: 0.265038
# [224]	valid_0's auc: 0.901553	valid_0's binary_logloss: 0.264993
# [225]	valid_0's auc: 0.901566	valid_0's binary_logloss: 0.264975
# [226]	valid_0's auc: 0.901594	valid_0's binary_logloss: 0.264927
# [227]	valid_0's auc: 0.90163	valid_0's binary_logloss: 0.264883
# [228]	valid_0's auc: 0.901677	valid_0's binary_logloss: 0.264821
# [229]	valid_0's auc: 0.901694	valid_0's binary_logloss: 0.264793
# [230]	valid_0's auc: 0.901706	valid_0's binary_logloss: 0.264773
# [231]	valid_0's auc: 0.901728	valid_0's binary_logloss: 0.26474
# [232]	valid_0's auc: 0.901755	valid_0's binary_logloss: 0.264704
# [233]	valid_0's auc: 0.9018	valid_0's binary_logloss: 0.264647
# [234]	valid_0's auc: 0.901833	valid_0's binary_logloss: 0.264607
# [235]	valid_0's auc: 0.901855	valid_0's binary_logloss: 0.264573
# [236]	valid_0's auc: 0.901886	valid_0's binary_logloss: 0.264532
# [237]	valid_0's auc: 0.901918	valid_0's binary_logloss: 0.264489
# [238]	valid_0's auc: 0.901942	valid_0's binary_logloss: 0.264454
# [239]	valid_0's auc: 0.901987	valid_0's binary_logloss: 0.2644
# [240]	valid_0's auc: 0.902029	valid_0's binary_logloss: 0.264344
# [241]	valid_0's auc: 0.902049	valid_0's binary_logloss: 0.264315
# [242]	valid_0's auc: 0.902071	valid_0's binary_logloss: 0.264288
# [243]	valid_0's auc: 0.902086	valid_0's binary_logloss: 0.264264
# [244]	valid_0's auc: 0.902105	valid_0's binary_logloss: 0.264241
# [245]	valid_0's auc: 0.902126	valid_0's binary_logloss: 0.264212
# [246]	valid_0's auc: 0.902157	valid_0's binary_logloss: 0.264177
# [247]	valid_0's auc: 0.902193	valid_0's binary_logloss: 0.26413
# [248]	valid_0's auc: 0.902214	valid_0's binary_logloss: 0.264101
# [249]	valid_0's auc: 0.902236	valid_0's binary_logloss: 0.264069
# [250]	valid_0's auc: 0.902248	valid_0's binary_logloss: 0.26405
# [251]	valid_0's auc: 0.902266	valid_0's binary_logloss: 0.26402
# [252]	valid_0's auc: 0.90229	valid_0's binary_logloss: 0.263988
# [253]	valid_0's auc: 0.90231	valid_0's binary_logloss: 0.263958
# [254]	valid_0's auc: 0.902334	valid_0's binary_logloss: 0.263927
# [255]	valid_0's auc: 0.902363	valid_0's binary_logloss: 0.263889
# [256]	valid_0's auc: 0.902377	valid_0's binary_logloss: 0.263868
# [257]	valid_0's auc: 0.902429	valid_0's binary_logloss: 0.263799
# [258]	valid_0's auc: 0.902449	valid_0's binary_logloss: 0.263769
# [259]	valid_0's auc: 0.902473	valid_0's binary_logloss: 0.263742
# [260]	valid_0's auc: 0.902505	valid_0's binary_logloss: 0.263695
# [261]	valid_0's auc: 0.902524	valid_0's binary_logloss: 0.263667
# [262]	valid_0's auc: 0.902545	valid_0's binary_logloss: 0.263636
# [263]	valid_0's auc: 0.902572	valid_0's binary_logloss: 0.263604
# [264]	valid_0's auc: 0.902585	valid_0's binary_logloss: 0.263587
# [265]	valid_0's auc: 0.902597	valid_0's binary_logloss: 0.263568
# [266]	valid_0's auc: 0.902629	valid_0's binary_logloss: 0.263523
# [267]	valid_0's auc: 0.90265	valid_0's binary_logloss: 0.263495
# [268]	valid_0's auc: 0.902668	valid_0's binary_logloss: 0.263468
# [269]	valid_0's auc: 0.9027	valid_0's binary_logloss: 0.263422
# [270]	valid_0's auc: 0.902719	valid_0's binary_logloss: 0.263387
# [271]	valid_0's auc: 0.902731	valid_0's binary_logloss: 0.26337
# [272]	valid_0's auc: 0.902749	valid_0's binary_logloss: 0.263348
# [273]	valid_0's auc: 0.902774	valid_0's binary_logloss: 0.263317
# [274]	valid_0's auc: 0.902796	valid_0's binary_logloss: 0.263287
# [275]	valid_0's auc: 0.902837	valid_0's binary_logloss: 0.263226
# [276]	valid_0's auc: 0.902846	valid_0's binary_logloss: 0.263212
# [277]	valid_0's auc: 0.902869	valid_0's binary_logloss: 0.263186
# [278]	valid_0's auc: 0.902877	valid_0's binary_logloss: 0.263175
# [279]	valid_0's auc: 0.902893	valid_0's binary_logloss: 0.263146
# [280]	valid_0's auc: 0.902913	valid_0's binary_logloss: 0.263116
# [281]	valid_0's auc: 0.902934	valid_0's binary_logloss: 0.263092
# [282]	valid_0's auc: 0.90295	valid_0's binary_logloss: 0.263067
# [283]	valid_0's auc: 0.902977	valid_0's binary_logloss: 0.26303
# [284]	valid_0's auc: 0.903002	valid_0's binary_logloss: 0.262996
# [285]	valid_0's auc: 0.903025	valid_0's binary_logloss: 0.262964
# [286]	valid_0's auc: 0.903036	valid_0's binary_logloss: 0.262948
# [287]	valid_0's auc: 0.903049	valid_0's binary_logloss: 0.262933
# [288]	valid_0's auc: 0.903077	valid_0's binary_logloss: 0.262895
# [289]	valid_0's auc: 0.903092	valid_0's binary_logloss: 0.262877
# [290]	valid_0's auc: 0.903112	valid_0's binary_logloss: 0.262849
# [291]	valid_0's auc: 0.903142	valid_0's binary_logloss: 0.262815
# [292]	valid_0's auc: 0.903156	valid_0's binary_logloss: 0.262791
# [293]	valid_0's auc: 0.903166	valid_0's binary_logloss: 0.262774
# [294]	valid_0's auc: 0.903192	valid_0's binary_logloss: 0.262738
# [295]	valid_0's auc: 0.903204	valid_0's binary_logloss: 0.262722
# [296]	valid_0's auc: 0.903216	valid_0's binary_logloss: 0.262708
# [297]	valid_0's auc: 0.903243	valid_0's binary_logloss: 0.262678
# [298]	valid_0's auc: 0.903266	valid_0's binary_logloss: 0.262651
# [299]	valid_0's auc: 0.90328	valid_0's binary_logloss: 0.262631
# [300]	valid_0's auc: 0.903302	valid_0's binary_logloss: 0.262597
# [301]	valid_0's auc: 0.903312	valid_0's binary_logloss: 0.262579
# [302]	valid_0's auc: 0.903321	valid_0's binary_logloss: 0.262567
# [303]	valid_0's auc: 0.903348	valid_0's binary_logloss: 0.262525
# [304]	valid_0's auc: 0.903359	valid_0's binary_logloss: 0.262511
# [305]	valid_0's auc: 0.903371	valid_0's binary_logloss: 0.262491
# [306]	valid_0's auc: 0.903383	valid_0's binary_logloss: 0.262476
# [307]	valid_0's auc: 0.903399	valid_0's binary_logloss: 0.262454
# [308]	valid_0's auc: 0.903417	valid_0's binary_logloss: 0.262428
# [309]	valid_0's auc: 0.903436	valid_0's binary_logloss: 0.262402
# [310]	valid_0's auc: 0.903445	valid_0's binary_logloss: 0.262389
# [311]	valid_0's auc: 0.903485	valid_0's binary_logloss: 0.262334
# [312]	valid_0's auc: 0.903509	valid_0's binary_logloss: 0.262303
# [313]	valid_0's auc: 0.903522	valid_0's binary_logloss: 0.262286
# [314]	valid_0's auc: 0.90354	valid_0's binary_logloss: 0.262263
# [315]	valid_0's auc: 0.903562	valid_0's binary_logloss: 0.262235
# [316]	valid_0's auc: 0.903573	valid_0's binary_logloss: 0.262221
# [317]	valid_0's auc: 0.903591	valid_0's binary_logloss: 0.262195
# [318]	valid_0's auc: 0.903608	valid_0's binary_logloss: 0.262173
# [319]	valid_0's auc: 0.903629	valid_0's binary_logloss: 0.262146
# [320]	valid_0's auc: 0.903637	valid_0's binary_logloss: 0.262133
# [321]	valid_0's auc: 0.903653	valid_0's binary_logloss: 0.262107
# [322]	valid_0's auc: 0.903684	valid_0's binary_logloss: 0.262062
# [323]	valid_0's auc: 0.903704	valid_0's binary_logloss: 0.262039
# [324]	valid_0's auc: 0.903713	valid_0's binary_logloss: 0.262027
# [325]	valid_0's auc: 0.903749	valid_0's binary_logloss: 0.261975
# [326]	valid_0's auc: 0.903756	valid_0's binary_logloss: 0.261966
# [327]	valid_0's auc: 0.903766	valid_0's binary_logloss: 0.261953
# [328]	valid_0's auc: 0.903779	valid_0's binary_logloss: 0.261937
# [329]	valid_0's auc: 0.903792	valid_0's binary_logloss: 0.261917
# [330]	valid_0's auc: 0.903807	valid_0's binary_logloss: 0.261895
# [331]	valid_0's auc: 0.903832	valid_0's binary_logloss: 0.261857
# [332]	valid_0's auc: 0.903861	valid_0's binary_logloss: 0.261822
# [333]	valid_0's auc: 0.903872	valid_0's binary_logloss: 0.261809
# [334]	valid_0's auc: 0.903878	valid_0's binary_logloss: 0.261801
# [335]	valid_0's auc: 0.903898	valid_0's binary_logloss: 0.261777
# [336]	valid_0's auc: 0.903926	valid_0's binary_logloss: 0.261734
# [337]	valid_0's auc: 0.903932	valid_0's binary_logloss: 0.261726
# [338]	valid_0's auc: 0.903959	valid_0's binary_logloss: 0.261695
# [339]	valid_0's auc: 0.903968	valid_0's binary_logloss: 0.261685
# [340]	valid_0's auc: 0.903979	valid_0's binary_logloss: 0.261669
# [341]	valid_0's auc: 0.903988	valid_0's binary_logloss: 0.261655
# [342]	valid_0's auc: 0.904008	valid_0's binary_logloss: 0.261627
# [343]	valid_0's auc: 0.904015	valid_0's binary_logloss: 0.261618
# [344]	valid_0's auc: 0.904035	valid_0's binary_logloss: 0.261586
# [345]	valid_0's auc: 0.904046	valid_0's binary_logloss: 0.261569
# [346]	valid_0's auc: 0.904054	valid_0's binary_logloss: 0.261557
# [347]	valid_0's auc: 0.904075	valid_0's binary_logloss: 0.26153
# [348]	valid_0's auc: 0.904099	valid_0's binary_logloss: 0.261502
# [349]	valid_0's auc: 0.904109	valid_0's binary_logloss: 0.261485
# [350]	valid_0's auc: 0.904121	valid_0's binary_logloss: 0.26147
# [351]	valid_0's auc: 0.90414	valid_0's binary_logloss: 0.261445
# [352]	valid_0's auc: 0.904147	valid_0's binary_logloss: 0.261434
# [353]	valid_0's auc: 0.904155	valid_0's binary_logloss: 0.261423
# [354]	valid_0's auc: 0.90417	valid_0's binary_logloss: 0.261404
# [355]	valid_0's auc: 0.90418	valid_0's binary_logloss: 0.261388
# [356]	valid_0's auc: 0.904191	valid_0's binary_logloss: 0.261372
# [357]	valid_0's auc: 0.904202	valid_0's binary_logloss: 0.261358
# [358]	valid_0's auc: 0.904212	valid_0's binary_logloss: 0.261341
# [359]	valid_0's auc: 0.904219	valid_0's binary_logloss: 0.26133
# [360]	valid_0's auc: 0.904227	valid_0's binary_logloss: 0.261318
# [361]	valid_0's auc: 0.90424	valid_0's binary_logloss: 0.261299
# [362]	valid_0's auc: 0.904252	valid_0's binary_logloss: 0.261282
# [363]	valid_0's auc: 0.904255	valid_0's binary_logloss: 0.261277
# [364]	valid_0's auc: 0.904261	valid_0's binary_logloss: 0.261271
# [365]	valid_0's auc: 0.904266	valid_0's binary_logloss: 0.261261
# [366]	valid_0's auc: 0.90427	valid_0's binary_logloss: 0.261255
# [367]	valid_0's auc: 0.904293	valid_0's binary_logloss: 0.261231
# [368]	valid_0's auc: 0.9043	valid_0's binary_logloss: 0.261223
# [369]	valid_0's auc: 0.904313	valid_0's binary_logloss: 0.261204
# [370]	valid_0's auc: 0.904323	valid_0's binary_logloss: 0.26119
# [371]	valid_0's auc: 0.904345	valid_0's binary_logloss: 0.261163
# [372]	valid_0's auc: 0.904352	valid_0's binary_logloss: 0.261152
# [373]	valid_0's auc: 0.904357	valid_0's binary_logloss: 0.261145
# [374]	valid_0's auc: 0.904364	valid_0's binary_logloss: 0.261135
# [375]	valid_0's auc: 0.904374	valid_0's binary_logloss: 0.26112
# [376]	valid_0's auc: 0.904384	valid_0's binary_logloss: 0.261104
# [377]	valid_0's auc: 0.904395	valid_0's binary_logloss: 0.261087
# [378]	valid_0's auc: 0.904416	valid_0's binary_logloss: 0.261062
# [379]	valid_0's auc: 0.904426	valid_0's binary_logloss: 0.261048
# [380]	valid_0's auc: 0.904447	valid_0's binary_logloss: 0.26102
# [381]	valid_0's auc: 0.904461	valid_0's binary_logloss: 0.261003
# [382]	valid_0's auc: 0.904467	valid_0's binary_logloss: 0.260994
# [383]	valid_0's auc: 0.904499	valid_0's binary_logloss: 0.260951
# [384]	valid_0's auc: 0.904505	valid_0's binary_logloss: 0.260942
# [385]	valid_0's auc: 0.90452	valid_0's binary_logloss: 0.260919
# [386]	valid_0's auc: 0.904527	valid_0's binary_logloss: 0.260912
# [387]	valid_0's auc: 0.904531	valid_0's binary_logloss: 0.260904
# [388]	valid_0's auc: 0.904543	valid_0's binary_logloss: 0.260888
# [389]	valid_0's auc: 0.904553	valid_0's binary_logloss: 0.26087
# [390]	valid_0's auc: 0.904561	valid_0's binary_logloss: 0.260861
# [391]	valid_0's auc: 0.904568	valid_0's binary_logloss: 0.260849
# [392]	valid_0's auc: 0.904573	valid_0's binary_logloss: 0.260843
# [393]	valid_0's auc: 0.90458	valid_0's binary_logloss: 0.260832
# [394]	valid_0's auc: 0.90461	valid_0's binary_logloss: 0.260791
# [395]	valid_0's auc: 0.904623	valid_0's binary_logloss: 0.260775
# [396]	valid_0's auc: 0.904629	valid_0's binary_logloss: 0.260768
# [397]	valid_0's auc: 0.904634	valid_0's binary_logloss: 0.260759
# [398]	valid_0's auc: 0.904641	valid_0's binary_logloss: 0.260749
# [399]	valid_0's auc: 0.904642	valid_0's binary_logloss: 0.260747
# [400]	valid_0's auc: 0.904649	valid_0's binary_logloss: 0.260737
# [401]	valid_0's auc: 0.904655	valid_0's binary_logloss: 0.26073
# [402]	valid_0's auc: 0.904661	valid_0's binary_logloss: 0.260719
# [403]	valid_0's auc: 0.904673	valid_0's binary_logloss: 0.260701
# [404]	valid_0's auc: 0.904693	valid_0's binary_logloss: 0.260674
# [405]	valid_0's auc: 0.904719	valid_0's binary_logloss: 0.260634
# [406]	valid_0's auc: 0.904723	valid_0's binary_logloss: 0.260628
# [407]	valid_0's auc: 0.904737	valid_0's binary_logloss: 0.260611
# [408]	valid_0's auc: 0.904747	valid_0's binary_logloss: 0.260594
# [409]	valid_0's auc: 0.904764	valid_0's binary_logloss: 0.260575
# [410]	valid_0's auc: 0.904775	valid_0's binary_logloss: 0.260559
# [411]	valid_0's auc: 0.904792	valid_0's binary_logloss: 0.260539
# [412]	valid_0's auc: 0.9048	valid_0's binary_logloss: 0.260527
# [413]	valid_0's auc: 0.904804	valid_0's binary_logloss: 0.260522
# [414]	valid_0's auc: 0.904824	valid_0's binary_logloss: 0.260501
# [415]	valid_0's auc: 0.904835	valid_0's binary_logloss: 0.260487
# [416]	valid_0's auc: 0.90484	valid_0's binary_logloss: 0.26048
# [417]	valid_0's auc: 0.90485	valid_0's binary_logloss: 0.260465
# [418]	valid_0's auc: 0.904883	valid_0's binary_logloss: 0.260418
# [419]	valid_0's auc: 0.904905	valid_0's binary_logloss: 0.260391
# [420]	valid_0's auc: 0.904909	valid_0's binary_logloss: 0.260384
# [421]	valid_0's auc: 0.904917	valid_0's binary_logloss: 0.260375
# [422]	valid_0's auc: 0.904922	valid_0's binary_logloss: 0.260369
# [423]	valid_0's auc: 0.904924	valid_0's binary_logloss: 0.260366
# [424]	valid_0's auc: 0.904927	valid_0's binary_logloss: 0.260361
# [425]	valid_0's auc: 0.90493	valid_0's binary_logloss: 0.260357
# [426]	valid_0's auc: 0.90494	valid_0's binary_logloss: 0.260344
# [427]	valid_0's auc: 0.904949	valid_0's binary_logloss: 0.260332
# [428]	valid_0's auc: 0.904955	valid_0's binary_logloss: 0.260323
# [429]	valid_0's auc: 0.90496	valid_0's binary_logloss: 0.260317
# [430]	valid_0's auc: 0.904976	valid_0's binary_logloss: 0.260295
# [431]	valid_0's auc: 0.90499	valid_0's binary_logloss: 0.260276
# [432]	valid_0's auc: 0.904998	valid_0's binary_logloss: 0.260264
# [433]	valid_0's auc: 0.905001	valid_0's binary_logloss: 0.26026
# [434]	valid_0's auc: 0.905003	valid_0's binary_logloss: 0.260257
# [435]	valid_0's auc: 0.905005	valid_0's binary_logloss: 0.260256
# [436]	valid_0's auc: 0.905009	valid_0's binary_logloss: 0.260249
# [437]	valid_0's auc: 0.905031	valid_0's binary_logloss: 0.260217
# [438]	valid_0's auc: 0.905039	valid_0's binary_logloss: 0.260207
# [439]	valid_0's auc: 0.905054	valid_0's binary_logloss: 0.26019
# [440]	valid_0's auc: 0.90506	valid_0's binary_logloss: 0.260181
# [441]	valid_0's auc: 0.905092	valid_0's binary_logloss: 0.260138
# [442]	valid_0's auc: 0.905103	valid_0's binary_logloss: 0.260125
# [443]	valid_0's auc: 0.905106	valid_0's binary_logloss: 0.260121
# [444]	valid_0's auc: 0.905112	valid_0's binary_logloss: 0.260107
# [445]	valid_0's auc: 0.905115	valid_0's binary_logloss: 0.260104
# [446]	valid_0's auc: 0.905128	valid_0's binary_logloss: 0.260085
# [447]	valid_0's auc: 0.905134	valid_0's binary_logloss: 0.260074
# [448]	valid_0's auc: 0.905147	valid_0's binary_logloss: 0.260052
# [449]	valid_0's auc: 0.905156	valid_0's binary_logloss: 0.260036
# [450]	valid_0's auc: 0.905165	valid_0's binary_logloss: 0.260024
# [451]	valid_0's auc: 0.905173	valid_0's binary_logloss: 0.260015
# [452]	valid_0's auc: 0.905177	valid_0's binary_logloss: 0.26001
# [453]	valid_0's auc: 0.905185	valid_0's binary_logloss: 0.259996
# [454]	valid_0's auc: 0.905191	valid_0's binary_logloss: 0.259988
# [455]	valid_0's auc: 0.905197	valid_0's binary_logloss: 0.259981
# [456]	valid_0's auc: 0.905207	valid_0's binary_logloss: 0.25997
# [457]	valid_0's auc: 0.905211	valid_0's binary_logloss: 0.259964
# [458]	valid_0's auc: 0.905216	valid_0's binary_logloss: 0.259958
# [459]	valid_0's auc: 0.905223	valid_0's binary_logloss: 0.259945
# [460]	valid_0's auc: 0.905226	valid_0's binary_logloss: 0.259942
# [461]	valid_0's auc: 0.905243	valid_0's binary_logloss: 0.259918
# [462]	valid_0's auc: 0.905254	valid_0's binary_logloss: 0.259904
# [463]	valid_0's auc: 0.905265	valid_0's binary_logloss: 0.259889
# [464]	valid_0's auc: 0.905276	valid_0's binary_logloss: 0.259875
# [465]	valid_0's auc: 0.905281	valid_0's binary_logloss: 0.259869
# [466]	valid_0's auc: 0.905295	valid_0's binary_logloss: 0.25985
# [467]	valid_0's auc: 0.905297	valid_0's binary_logloss: 0.259847
# [468]	valid_0's auc: 0.9053	valid_0's binary_logloss: 0.259842
# [469]	valid_0's auc: 0.905307	valid_0's binary_logloss: 0.259832
# [470]	valid_0's auc: 0.905311	valid_0's binary_logloss: 0.259826
# [471]	valid_0's auc: 0.905319	valid_0's binary_logloss: 0.259813
# [472]	valid_0's auc: 0.905323	valid_0's binary_logloss: 0.259806
# [473]	valid_0's auc: 0.905356	valid_0's binary_logloss: 0.259762
# [474]	valid_0's auc: 0.90536	valid_0's binary_logloss: 0.259755
# [475]	valid_0's auc: 0.905373	valid_0's binary_logloss: 0.25974
# [476]	valid_0's auc: 0.905379	valid_0's binary_logloss: 0.25973
# [477]	valid_0's auc: 0.905382	valid_0's binary_logloss: 0.259725
# [478]	valid_0's auc: 0.905386	valid_0's binary_logloss: 0.25972
# [479]	valid_0's auc: 0.905391	valid_0's binary_logloss: 0.259714
# [480]	valid_0's auc: 0.905393	valid_0's binary_logloss: 0.259711
# [481]	valid_0's auc: 0.905412	valid_0's binary_logloss: 0.259686
# [482]	valid_0's auc: 0.905424	valid_0's binary_logloss: 0.25967
# [483]	valid_0's auc: 0.905426	valid_0's binary_logloss: 0.259667
# [484]	valid_0's auc: 0.90543	valid_0's binary_logloss: 0.259661
# [485]	valid_0's auc: 0.905436	valid_0's binary_logloss: 0.259654
# [486]	valid_0's auc: 0.905453	valid_0's binary_logloss: 0.259634
# [487]	valid_0's auc: 0.905459	valid_0's binary_logloss: 0.259625
# [488]	valid_0's auc: 0.905462	valid_0's binary_logloss: 0.259619
# [489]	valid_0's auc: 0.905472	valid_0's binary_logloss: 0.259608
# [490]	valid_0's auc: 0.905479	valid_0's binary_logloss: 0.259599
# [491]	valid_0's auc: 0.905481	valid_0's binary_logloss: 0.259595
# [492]	valid_0's auc: 0.905498	valid_0's binary_logloss: 0.259572
# [493]	valid_0's auc: 0.905501	valid_0's binary_logloss: 0.25957
# [494]	valid_0's auc: 0.905504	valid_0's binary_logloss: 0.259564
# [495]	valid_0's auc: 0.905505	valid_0's binary_logloss: 0.259563
# [496]	valid_0's auc: 0.905506	valid_0's binary_logloss: 0.259561
# [497]	valid_0's auc: 0.905518	valid_0's binary_logloss: 0.259548
# [498]	valid_0's auc: 0.905522	valid_0's binary_logloss: 0.259543
# [499]	valid_0's auc: 0.905528	valid_0's binary_logloss: 0.259535
# [500]	valid_0's auc: 0.905533	valid_0's binary_logloss: 0.259526
# [501]	valid_0's auc: 0.905538	valid_0's binary_logloss: 0.25952
# [502]	valid_0's auc: 0.905544	valid_0's binary_logloss: 0.259513
# [503]	valid_0's auc: 0.905546	valid_0's binary_logloss: 0.25951
# [504]	valid_0's auc: 0.905549	valid_0's binary_logloss: 0.259504
# [505]	valid_0's auc: 0.905562	valid_0's binary_logloss: 0.259491
# [506]	valid_0's auc: 0.905561	valid_0's binary_logloss: 0.259492
# [507]	valid_0's auc: 0.905564	valid_0's binary_logloss: 0.259489
# [508]	valid_0's auc: 0.905575	valid_0's binary_logloss: 0.259475
# [509]	valid_0's auc: 0.905584	valid_0's binary_logloss: 0.259463
# [510]	valid_0's auc: 0.905589	valid_0's binary_logloss: 0.259452
# [511]	valid_0's auc: 0.905592	valid_0's binary_logloss: 0.259448
# [512]	valid_0's auc: 0.905594	valid_0's binary_logloss: 0.259447
# [513]	valid_0's auc: 0.905599	valid_0's binary_logloss: 0.259441
# [514]	valid_0's auc: 0.905609	valid_0's binary_logloss: 0.259427
# [515]	valid_0's auc: 0.905612	valid_0's binary_logloss: 0.259424
# [516]	valid_0's auc: 0.905617	valid_0's binary_logloss: 0.259418
# [517]	valid_0's auc: 0.905619	valid_0's binary_logloss: 0.259415
# [518]	valid_0's auc: 0.905628	valid_0's binary_logloss: 0.259402
# [519]	valid_0's auc: 0.905645	valid_0's binary_logloss: 0.25938
# [520]	valid_0's auc: 0.905648	valid_0's binary_logloss: 0.259376
# [521]	valid_0's auc: 0.90565	valid_0's binary_logloss: 0.259373
# [522]	valid_0's auc: 0.905654	valid_0's binary_logloss: 0.259367
# [523]	valid_0's auc: 0.905659	valid_0's binary_logloss: 0.259359
# [524]	valid_0's auc: 0.905664	valid_0's binary_logloss: 0.259352
# [525]	valid_0's auc: 0.905673	valid_0's binary_logloss: 0.259338
# [526]	valid_0's auc: 0.905675	valid_0's binary_logloss: 0.259335
# [527]	valid_0's auc: 0.905684	valid_0's binary_logloss: 0.259325
# [528]	valid_0's auc: 0.905688	valid_0's binary_logloss: 0.25932
# [529]	valid_0's auc: 0.9057	valid_0's binary_logloss: 0.259307
# [530]	valid_0's auc: 0.905702	valid_0's binary_logloss: 0.259303
# [531]	valid_0's auc: 0.905706	valid_0's binary_logloss: 0.259298
# [532]	valid_0's auc: 0.905711	valid_0's binary_logloss: 0.259293
# [533]	valid_0's auc: 0.905715	valid_0's binary_logloss: 0.259286
# [534]	valid_0's auc: 0.905718	valid_0's binary_logloss: 0.259283
# [535]	valid_0's auc: 0.905726	valid_0's binary_logloss: 0.25927
# [536]	valid_0's auc: 0.905733	valid_0's binary_logloss: 0.25926
# [537]	valid_0's auc: 0.905742	valid_0's binary_logloss: 0.259248
# [538]	valid_0's auc: 0.905763	valid_0's binary_logloss: 0.259226
# [539]	valid_0's auc: 0.905769	valid_0's binary_logloss: 0.259218
# [540]	valid_0's auc: 0.905778	valid_0's binary_logloss: 0.259208
# [541]	valid_0's auc: 0.905786	valid_0's binary_logloss: 0.259199
# [542]	valid_0's auc: 0.905794	valid_0's binary_logloss: 0.25919
# [543]	valid_0's auc: 0.905801	valid_0's binary_logloss: 0.259183
# [544]	valid_0's auc: 0.90581	valid_0's binary_logloss: 0.25917
# [545]	valid_0's auc: 0.905812	valid_0's binary_logloss: 0.259167
# [546]	valid_0's auc: 0.905823	valid_0's binary_logloss: 0.259152
# [547]	valid_0's auc: 0.905833	valid_0's binary_logloss: 0.259142
# [548]	valid_0's auc: 0.905845	valid_0's binary_logloss: 0.259126
# [549]	valid_0's auc: 0.905849	valid_0's binary_logloss: 0.259119
# [550]	valid_0's auc: 0.905855	valid_0's binary_logloss: 0.259113
# [551]	valid_0's auc: 0.905857	valid_0's binary_logloss: 0.259111
# [552]	valid_0's auc: 0.905862	valid_0's binary_logloss: 0.259105
# [553]	valid_0's auc: 0.905866	valid_0's binary_logloss: 0.259099
# [554]	valid_0's auc: 0.905877	valid_0's binary_logloss: 0.259085
# [555]	valid_0's auc: 0.905897	valid_0's binary_logloss: 0.259061
# [556]	valid_0's auc: 0.905898	valid_0's binary_logloss: 0.259059
# [557]	valid_0's auc: 0.905899	valid_0's binary_logloss: 0.259055
# [558]	valid_0's auc: 0.905908	valid_0's binary_logloss: 0.25904
# [559]	valid_0's auc: 0.905918	valid_0's binary_logloss: 0.259028
# [560]	valid_0's auc: 0.905921	valid_0's binary_logloss: 0.259024
# [561]	valid_0's auc: 0.905925	valid_0's binary_logloss: 0.259017
# [562]	valid_0's auc: 0.905936	valid_0's binary_logloss: 0.259003
# [563]	valid_0's auc: 0.905935	valid_0's binary_logloss: 0.259003
# [564]	valid_0's auc: 0.905937	valid_0's binary_logloss: 0.259001
# [565]	valid_0's auc: 0.905939	valid_0's binary_logloss: 0.258999
# [566]	valid_0's auc: 0.905943	valid_0's binary_logloss: 0.258994
# [567]	valid_0's auc: 0.905943	valid_0's binary_logloss: 0.258993
# [568]	valid_0's auc: 0.905956	valid_0's binary_logloss: 0.258979
# [569]	valid_0's auc: 0.905958	valid_0's binary_logloss: 0.258976
# [570]	valid_0's auc: 0.905966	valid_0's binary_logloss: 0.258965
# [571]	valid_0's auc: 0.905969	valid_0's binary_logloss: 0.25896
# [572]	valid_0's auc: 0.905973	valid_0's binary_logloss: 0.258956
# [573]	valid_0's auc: 0.905976	valid_0's binary_logloss: 0.258951
# [574]	valid_0's auc: 0.905985	valid_0's binary_logloss: 0.25894
# [575]	valid_0's auc: 0.905987	valid_0's binary_logloss: 0.258938
# [576]	valid_0's auc: 0.905991	valid_0's binary_logloss: 0.258934
# [577]	valid_0's auc: 0.905994	valid_0's binary_logloss: 0.258929
# [578]	valid_0's auc: 0.905996	valid_0's binary_logloss: 0.258926
# [579]	valid_0's auc: 0.906002	valid_0's binary_logloss: 0.258919
# [580]	valid_0's auc: 0.906027	valid_0's binary_logloss: 0.258882
# [581]	valid_0's auc: 0.906036	valid_0's binary_logloss: 0.258872
# [582]	valid_0's auc: 0.906045	valid_0's binary_logloss: 0.258859
# [583]	valid_0's auc: 0.906056	valid_0's binary_logloss: 0.258846
# [584]	valid_0's auc: 0.906059	valid_0's binary_logloss: 0.258842
# [585]	valid_0's auc: 0.906067	valid_0's binary_logloss: 0.258832
# [586]	valid_0's auc: 0.906075	valid_0's binary_logloss: 0.258819
# [587]	valid_0's auc: 0.906078	valid_0's binary_logloss: 0.258816
# [588]	valid_0's auc: 0.906082	valid_0's binary_logloss: 0.258811
# [589]	valid_0's auc: 0.906088	valid_0's binary_logloss: 0.2588
# [590]	valid_0's auc: 0.906094	valid_0's binary_logloss: 0.258791
# [591]	valid_0's auc: 0.906097	valid_0's binary_logloss: 0.258786
# [592]	valid_0's auc: 0.906103	valid_0's binary_logloss: 0.258775
# [593]	valid_0's auc: 0.90611	valid_0's binary_logloss: 0.258766
# [594]	valid_0's auc: 0.906112	valid_0's binary_logloss: 0.258763
# [595]	valid_0's auc: 0.906117	valid_0's binary_logloss: 0.258758
# [596]	valid_0's auc: 0.906123	valid_0's binary_logloss: 0.25875
# [597]	valid_0's auc: 0.906128	valid_0's binary_logloss: 0.258744
# [598]	valid_0's auc: 0.906134	valid_0's binary_logloss: 0.258735
# [599]	valid_0's auc: 0.906135	valid_0's binary_logloss: 0.258734
# [600]	valid_0's auc: 0.906141	valid_0's binary_logloss: 0.258727
# [601]	valid_0's auc: 0.906146	valid_0's binary_logloss: 0.25872
# [602]	valid_0's auc: 0.906154	valid_0's binary_logloss: 0.25871
# [603]	valid_0's auc: 0.906164	valid_0's binary_logloss: 0.258694
# [604]	valid_0's auc: 0.906169	valid_0's binary_logloss: 0.258688
# [605]	valid_0's auc: 0.906169	valid_0's binary_logloss: 0.258687
# [606]	valid_0's auc: 0.906178	valid_0's binary_logloss: 0.258676
# [607]	valid_0's auc: 0.90618	valid_0's binary_logloss: 0.258673
# [608]	valid_0's auc: 0.90619	valid_0's binary_logloss: 0.258661
# [609]	valid_0's auc: 0.906197	valid_0's binary_logloss: 0.258649
# [610]	valid_0's auc: 0.906205	valid_0's binary_logloss: 0.258637
# [611]	valid_0's auc: 0.906206	valid_0's binary_logloss: 0.258635
# [612]	valid_0's auc: 0.906209	valid_0's binary_logloss: 0.258628
# [613]	valid_0's auc: 0.906215	valid_0's binary_logloss: 0.258621
# [614]	valid_0's auc: 0.906218	valid_0's binary_logloss: 0.258617
# [615]	valid_0's auc: 0.906227	valid_0's binary_logloss: 0.258608
# [616]	valid_0's auc: 0.906227	valid_0's binary_logloss: 0.258608
# [617]	valid_0's auc: 0.906233	valid_0's binary_logloss: 0.258602
# [618]	valid_0's auc: 0.906239	valid_0's binary_logloss: 0.258594
# [619]	valid_0's auc: 0.906247	valid_0's binary_logloss: 0.258579
# [620]	valid_0's auc: 0.906251	valid_0's binary_logloss: 0.258576
# [621]	valid_0's auc: 0.906254	valid_0's binary_logloss: 0.258572
# [622]	valid_0's auc: 0.906256	valid_0's binary_logloss: 0.25857
# [623]	valid_0's auc: 0.90626	valid_0's binary_logloss: 0.258566
# [624]	valid_0's auc: 0.906265	valid_0's binary_logloss: 0.25856
# [625]	valid_0's auc: 0.906271	valid_0's binary_logloss: 0.258552
# [626]	valid_0's auc: 0.906275	valid_0's binary_logloss: 0.258548
# [627]	valid_0's auc: 0.906282	valid_0's binary_logloss: 0.258539
# [628]	valid_0's auc: 0.906285	valid_0's binary_logloss: 0.258534
# [629]	valid_0's auc: 0.906287	valid_0's binary_logloss: 0.258532
# [630]	valid_0's auc: 0.906287	valid_0's binary_logloss: 0.258532
# [631]	valid_0's auc: 0.906288	valid_0's binary_logloss: 0.258531
# [632]	valid_0's auc: 0.906291	valid_0's binary_logloss: 0.258527
# [633]	valid_0's auc: 0.906295	valid_0's binary_logloss: 0.258522
# [634]	valid_0's auc: 0.906297	valid_0's binary_logloss: 0.258518
# [635]	valid_0's auc: 0.9063	valid_0's binary_logloss: 0.258512
# [636]	valid_0's auc: 0.906306	valid_0's binary_logloss: 0.258504
# [637]	valid_0's auc: 0.906311	valid_0's binary_logloss: 0.258498
# [638]	valid_0's auc: 0.906316	valid_0's binary_logloss: 0.258492
# [639]	valid_0's auc: 0.906318	valid_0's binary_logloss: 0.258489
# [640]	valid_0's auc: 0.906321	valid_0's binary_logloss: 0.258483
# [641]	valid_0's auc: 0.906334	valid_0's binary_logloss: 0.258462
# [642]	valid_0's auc: 0.90634	valid_0's binary_logloss: 0.258455
# [643]	valid_0's auc: 0.90634	valid_0's binary_logloss: 0.258454
# [644]	valid_0's auc: 0.906358	valid_0's binary_logloss: 0.258426
# [645]	valid_0's auc: 0.906362	valid_0's binary_logloss: 0.258419
# [646]	valid_0's auc: 0.906369	valid_0's binary_logloss: 0.258411
# [647]	valid_0's auc: 0.906375	valid_0's binary_logloss: 0.258401
# [648]	valid_0's auc: 0.906381	valid_0's binary_logloss: 0.258394
# [649]	valid_0's auc: 0.906383	valid_0's binary_logloss: 0.258391
# [650]	valid_0's auc: 0.906384	valid_0's binary_logloss: 0.25839
# [651]	valid_0's auc: 0.906397	valid_0's binary_logloss: 0.258369
# [652]	valid_0's auc: 0.906399	valid_0's binary_logloss: 0.258367
# [653]	valid_0's auc: 0.9064	valid_0's binary_logloss: 0.258364
# [654]	valid_0's auc: 0.906403	valid_0's binary_logloss: 0.258362
# [655]	valid_0's auc: 0.906405	valid_0's binary_logloss: 0.258358
# [656]	valid_0's auc: 0.906406	valid_0's binary_logloss: 0.258357
# [657]	valid_0's auc: 0.906406	valid_0's binary_logloss: 0.258356
# [658]	valid_0's auc: 0.906415	valid_0's binary_logloss: 0.258348
# [659]	valid_0's auc: 0.906429	valid_0's binary_logloss: 0.25833
# [660]	valid_0's auc: 0.906438	valid_0's binary_logloss: 0.258319
# [661]	valid_0's auc: 0.906445	valid_0's binary_logloss: 0.25831
# [662]	valid_0's auc: 0.90645	valid_0's binary_logloss: 0.258305
# [663]	valid_0's auc: 0.906453	valid_0's binary_logloss: 0.258302
# [664]	valid_0's auc: 0.90646	valid_0's binary_logloss: 0.258293
# [665]	valid_0's auc: 0.906465	valid_0's binary_logloss: 0.258284
# [666]	valid_0's auc: 0.90647	valid_0's binary_logloss: 0.258278
# [667]	valid_0's auc: 0.90647	valid_0's binary_logloss: 0.258278
# [668]	valid_0's auc: 0.906473	valid_0's binary_logloss: 0.258275
# [669]	valid_0's auc: 0.906476	valid_0's binary_logloss: 0.25827
# [670]	valid_0's auc: 0.906482	valid_0's binary_logloss: 0.258262
# [671]	valid_0's auc: 0.906491	valid_0's binary_logloss: 0.258251
# [672]	valid_0's auc: 0.906493	valid_0's binary_logloss: 0.258249
# [673]	valid_0's auc: 0.906494	valid_0's binary_logloss: 0.258247
# [674]	valid_0's auc: 0.9065	valid_0's binary_logloss: 0.25824
# [675]	valid_0's auc: 0.906502	valid_0's binary_logloss: 0.258237
# [676]	valid_0's auc: 0.90651	valid_0's binary_logloss: 0.258226
# [677]	valid_0's auc: 0.906512	valid_0's binary_logloss: 0.258222
# [678]	valid_0's auc: 0.906516	valid_0's binary_logloss: 0.258217
# [679]	valid_0's auc: 0.906518	valid_0's binary_logloss: 0.258215
# [680]	valid_0's auc: 0.906523	valid_0's binary_logloss: 0.258209
# [681]	valid_0's auc: 0.906537	valid_0's binary_logloss: 0.258189
# [682]	valid_0's auc: 0.906536	valid_0's binary_logloss: 0.25819
# [683]	valid_0's auc: 0.906539	valid_0's binary_logloss: 0.258186
# [684]	valid_0's auc: 0.906541	valid_0's binary_logloss: 0.258184
# [685]	valid_0's auc: 0.906542	valid_0's binary_logloss: 0.258183
# [686]	valid_0's auc: 0.906549	valid_0's binary_logloss: 0.258173
# [687]	valid_0's auc: 0.906559	valid_0's binary_logloss: 0.258164
# [688]	valid_0's auc: 0.906565	valid_0's binary_logloss: 0.258156
# [689]	valid_0's auc: 0.906566	valid_0's binary_logloss: 0.258155
# [690]	valid_0's auc: 0.906573	valid_0's binary_logloss: 0.258147
# [691]	valid_0's auc: 0.906583	valid_0's binary_logloss: 0.258137
# [692]	valid_0's auc: 0.906589	valid_0's binary_logloss: 0.25813
# [693]	valid_0's auc: 0.906596	valid_0's binary_logloss: 0.258119
# [694]	valid_0's auc: 0.906601	valid_0's binary_logloss: 0.258111
# [695]	valid_0's auc: 0.90661	valid_0's binary_logloss: 0.258098
# [696]	valid_0's auc: 0.906618	valid_0's binary_logloss: 0.258089
# [697]	valid_0's auc: 0.90662	valid_0's binary_logloss: 0.258087
# [698]	valid_0's auc: 0.906623	valid_0's binary_logloss: 0.258083
# [699]	valid_0's auc: 0.906642	valid_0's binary_logloss: 0.258051
# [700]	valid_0's auc: 0.906649	valid_0's binary_logloss: 0.258042
# Did not meet early stopping. Best iteration is:
# [700]	valid_0's auc: 0.906649	valid_0's binary_logloss: 0.258042

# %%
model = load_obj("model.model_lgb_777")
